# %% [markdown]
# # Espectro de absorcon del etanol

# %%
import matplotlib.pyplot as plt

## Datos de longitud de onda y absorbancia experimentales para el etanol 
longitud_onda = [
    400, 410, 420, 422, 424, 426, 428, 430, 432, 434, 436, 438, 440,
    450, 452, 454, 456, 458, 460, 470, 480, 490, 500, 510, 520, 530,
    540, 550, 560, 570, 580, 590, 600, 610, 620, 630, 640, 642, 644,
    646, 648, 650, 652, 654, 656, 658, 660, 662, 664, 666, 668, 670,
    680, 690, 700
]

absorbancia = [
    1.115, 1.040, 0.928, 0.916, 0.898, 0.878, 0.862, 0.850, 0.840, 0.830,
    0.820, 0.810, 0.800, 0.742, 0.726, 0.720, 0.720, 0.724, 0.730, 0.882,
    1.225, 1.195, 0.940, 0.774, 0.653, 0.568, 0.510, 0.463, 0.430, 0.398,
    0.380, 0.366, 0.353, 0.343, 0.332, 0.321, 0.319, 0.353, 0.416, 0.475,
    0.508, 0.515, 0.497, 0.493, 0.491, 0.487, 0.485, 0.482, 0.480, 0.480,
    0.482, 0.485, 0.453, 0.276, 0.217
]

## Graficamos los resultados
plt.figure(figsize=(10, 6))
plt.plot(longitud_onda, absorbancia, marker='o', linestyle='-', color='b', label='Absorbancia')
plt.title("Espectro de Absorbancia - Etanol", fontsize=16)
plt.xlabel("Longitud de onda (nm)", fontsize=14)
plt.ylabel("Absorbancia (u.a.)", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=12)
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# # Espectro de absorción de la clorofila

# %%
import matplotlib.pyplot as plt

## Datos experimentalmente obtenidos para la clorofila
longitud_onda_2 = [
    410, 420, 422, 424, 426, 428, 430, 432, 434, 436, 438, 440,
    450, 460, 470, 480, 490, 500, 510, 520, 530, 540, 550, 560,
    570, 580, 590, 600, 610, 620, 630, 640, 642, 644, 646, 648,
    650, 652, 654, 656, 658, 660, 662, 664, 666, 668, 670, 672,
    674, 676, 678, 680, 682, 684, 686, 688, 690, 700
]
absorbancia_2 = [
    1.960, 1.820, 1.780, 1.780, 1.780, 1.780, 1.780, 1.780, 1.760, 1.760, 1.740, 1.720,
    1.510, 1.430, 1.530, 1.740, 1.570, 1.155, 0.916, 0.776, 0.683, 0.614, 0.561, 0.528,
    0.500, 0.481, 0.469, 0.467, 0.453, 0.443, 0.429, 0.439, 0.476, 0.552, 0.617, 0.667,
    0.683, 0.680, 0.690, 0.706, 0.718, 0.728, 0.750, 0.758, 0.764, 0.762, 0.758, 0.738,
    0.724, 0.700, 0.656, 0.601, 0.530, 0.478, 0.425, 0.384, 0.346, 0.262
]

## Gráficamos
plt.figure(figsize=(12, 6))
plt.plot(longitud_onda_2, absorbancia_2, marker='o', label="Absorbancia vs Longitud de onda")
plt.title("Espectro de Absorbancia - Clorofila", fontsize=14)
plt.xlabel("Longitud de onda (nm)", fontsize=12)
plt.ylabel("Absorbancia (u.a.)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# # Espectro de abosrción de ambas graficas superpuestos

# %%
## Importamos libreria para graficar
import matplotlib.pyplot as plt

##Valores para el etanol

longitud_onda = [
    400, 410, 420, 422, 424, 426, 428, 430, 432, 434, 436, 438, 440,
    450, 452, 454, 456, 458, 460, 470, 480, 490, 500, 510, 520, 530,
    540, 550, 560, 570, 580, 590, 600, 610, 620, 630, 640, 642, 644,
    646, 648, 650, 652, 654, 656, 658, 660, 662, 664, 666, 668, 670,
    680, 690, 700
]

absorbancia = [
    1.115, 1.040, 0.928, 0.916, 0.898, 0.878, 0.862, 0.850, 0.840, 0.830,
    0.820, 0.810, 0.800, 0.742, 0.726, 0.720, 0.720, 0.724, 0.730, 0.882,
    1.225, 1.195, 0.940, 0.774, 0.653, 0.568, 0.510, 0.463, 0.430, 0.398,
    0.380, 0.366, 0.353, 0.343, 0.332, 0.321, 0.319, 0.353, 0.416, 0.475,
    0.508, 0.515, 0.497, 0.493, 0.491, 0.487, 0.485, 0.482, 0.480, 0.480,
    0.482, 0.485, 0.453, 0.276, 0.217
]

##Valores para la clorofila

longitud_onda_2 = [
    410, 420, 422, 424, 426, 428, 430, 432, 434, 436, 438, 440,
    450, 460, 470, 480, 490, 500, 510, 520, 530, 540, 550, 560,
    570, 580, 590, 600, 610, 620, 630, 640, 642, 644, 646, 648,
    650, 652, 654, 656, 658, 660, 662, 664, 666, 668, 670, 672,
    674, 676, 678, 680, 682, 684, 686, 688, 690, 700
]
absorbancia_2 = [
    1.960, 1.820, 1.780, 1.780, 1.780, 1.780, 1.780, 1.780, 1.760, 1.760, 1.740, 1.720,
    1.510, 1.430, 1.530, 1.740, 1.570, 1.155, 0.916, 0.776, 0.683, 0.614, 0.561, 0.528,
    0.500, 0.481, 0.469, 0.467, 0.453, 0.443, 0.429, 0.439, 0.476, 0.552, 0.617, 0.667,
    0.683, 0.680, 0.690, 0.706, 0.718, 0.728, 0.750, 0.758, 0.764, 0.762, 0.758, 0.738,
    0.724, 0.700, 0.656, 0.601, 0.530, 0.478, 0.425, 0.384, 0.346, 0.262
]

## Creamos la gráfica
plt.figure(figsize=(10, 6))
plt.plot(longitud_onda, absorbancia, marker='o', linestyle='-', color='red', label='Absorbancia Etanol')
plt.plot(longitud_onda_2, absorbancia_2, marker='o',color= 'green', label="Absorbancia Clorofila")
plt.xlabel('Absorbancia (u.a.)')
plt.ylabel('Longitud de onda (nm))')
plt.title('Comparación de espectros de absorción')
plt.legend()
plt.grid(True)
