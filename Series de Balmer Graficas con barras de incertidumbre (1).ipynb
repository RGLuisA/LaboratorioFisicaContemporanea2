# %% [markdown]
# # Gráficas con barras de incertidumbre

# %% [markdown]
# ### Sodio

# %%
import matplotlib.pyplot as plt

## Vaciamos los datos experimentales en dos arreglos 
longitud_onda = [440, 460, 480, 500, 520, 540, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596, 597, 598, 599, 600, 620, 640, 660, 680, 700]
corriente = [1.0, 0.1, 0.12, 0.25, 0.13, 0.18, 0.58, 9.0, 12.0, 15.0, 18.0, 21.0, 22.0, 22.0, 22.0, 21.0, 20.0, 18.0, 17.0, 16.0, 15.0, 13.0, 13.0, 15.0, 17.0, 20.0, 54.0, 350.0, 350.0, 340.0, 360.0, 380.0, 390.0, 400.0, 390.0, 390.0, 380.0, 370.0, 350.0, 340.0, 340.0, 340.0, 230.0, 40.0, 1.9, 1.6, 1.4, 3.6, 1.9, 1.3, 1.0, 1.2]

## Definimos nuestros errores constantes en nuestra escala
error_longitud_onda = 0.05
error_corriente = 0.02

## Hacemos la grafica esta vez con las barras de error/incertidumbre
plt.figure(figsize=(10, 6))
plt.errorbar(longitud_onda, corriente, 
             xerr=error_longitud_onda, yerr=error_corriente, 
             fmt='o', linestyle='-', color='b', capsize=4, elinewidth=1, markeredgewidth=2, markersize=5)

## Definimos las etiquetas y título
plt.xlabel('Longitud de onda (nm)')
plt.ylabel('Intensidad de corriente ($\times 10^{-4}$ A)')
plt.title('Gráfica de Longitud de onda vs Intensidad de corriente')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Hidrogeno

# %%
import matplotlib.pyplot as plt

# Vacíamos los datos en arrays para su manipulación y los convertimos a la magnitud de 10^-4 A (para la intensidad de corriente)
longitud_onda = [
    395, 400, 403, 408, 412, 416, 420, 426, 429, 432, 435, 438, 441, 444, 447, 
    460, 470, 480, 490, 500, 510, 520, 530, 535, 540, 541, 542, 543, 543, 544, 
    545, 546, 547, 548, 549, 550, 551, 552, 553, 555, 560, 565, 570, 571, 572, 
    573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583
]
corriente = [
    2.2, 4.6, 5.1, 4.5, 2.7, 2.6, 2.6, 4.0, 5.4, 5.7, 6.0, 5.8, 5.8, 2.3, 2.0, 
    2.2, 2.0, 1.8, 1.9, 1.5, 5.5, 1.5, 2.4, 2.3, 5.5, 6.0, 6.1, 6.3, 6.3, 6.4, 
    6.4, 6.4, 6.3, 6.3, 6.2, 6.1, 6.0, 5.8, 5.4, 2.8, 2.0, 1.9, 3.6, 4.1, 4.5, 
    4.9, 5.1, 5.2, 5.4, 5.5, 5.5, 5.5, 5.4, 5.3, 5.1, 4.8
]

# Incertidumbres en longitud de onda y corriente
error_longitud_onda = 0.05  # Error constante en longitud de onda (nm)
error_corriente = 0.02  # Error constante en corriente (10^-4 A)

# Hacemos la gráfica con barras de error
plt.figure(figsize=(12, 8))
plt.errorbar(longitud_onda, corriente, xerr=error_longitud_onda, yerr=error_corriente, fmt='o', linestyle='-', color='r', ecolor='black', capsize=3, label='Datos experimentales')

# Etiquetas y configuración de la gráfica
plt.xlabel('Longitud de onda (nm)')
plt.ylabel('Intensidad de corriente ($\times 10^{-4}$ A)')
plt.title('Gráfica de Longitud de onda vs Intensidad de corriente (Lámpara de Hidrógeno)')
plt.xlim(min(longitud_onda) - 10, max(longitud_onda) + 10)
plt.ylim(0, max(corriente) * 1.1)
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

## Vaciamos nuestros datos experimentalmente obtenidos en dos arreglos
longitud_onda = [
    395, 400, 403, 408, 412, 416, 420, 426, 429, 432, 435, 438, 441, 444, 447, 
    460, 470, 480, 490, 500, 510, 520, 530, 535, 540, 541, 542, 543, 543, 544, 
    545, 546, 547, 548, 549, 550, 551, 552, 553, 555, 560, 565, 570, 571, 572, 
    573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583
]

corriente = [
    2.2, 4.6, 5.1, 4.5, 2.7, 2.6, 2.6, 4.0, 5.4, 5.7, 6.0, 5.8, 5.8, 2.3, 2.0, 
    2.2, 2.0, 1.8, 1.9, 1.5, 5.5, 1.5, 2.4, 2.3, 5.5, 6.0, 6.1, 6.3, 6.3, 6.4, 
    6.4, 6.4, 6.3, 6.3, 6.2, 6.1, 6.0, 5.8, 5.4, 2.8, 2.0, 1.9, 3.6, 4.1, 4.5, 
    4.9, 5.1, 5.2, 5.4, 5.5, 5.5, 5.5, 5.4, 5.3, 5.1, 4.8
]

## Definimos nuestros errores que van a ser constantes para la escala en que trabajamos
error_longitud_onda = 0.05
error_corriente = 0.02

## Hacemos las graficas esta vez con las barras de error
plt.figure(figsize=(12, 8))
plt.errorbar(longitud_onda, corriente, 
             xerr=error_longitud_onda, yerr=error_corriente, 
             fmt='o', linestyle='-', color='r', capsize=5, elinewidth=2, markeredgewidth=2)

## Ponemos las etiquetas y títulos correspondientes al grafico
plt.xlabel('Longitud de onda (nm)')
plt.ylabel('Intensidad de corriente ($\times 10^{-4}$ A)')
plt.title('Gráfica de Longitud de onda vs Intensidad de corriente (Lámpara de Hidrógeno)')
plt.xlim(min(longitud_onda) - 10, max(longitud_onda) + 10)
plt.ylim(0, max(corriente) * 1.1)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

## Vaciamos nuestros datos experimentales en dos arreglos
longitud_onda = [
    395, 400, 403, 408, 412, 416, 420, 426, 429, 432, 435, 438, 441, 444, 447, 
    460, 470, 480, 490, 500, 510, 520, 530, 535, 540, 541, 542, 543, 543, 544, 
    545, 546, 547, 548, 549, 550, 551, 552, 553, 555, 560, 565, 570, 571, 572, 
    573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583
]

corriente = [
    2.2, 4.6, 5.1, 4.5, 2.7, 2.6, 2.6, 4.0, 5.4, 5.7, 6.0, 5.8, 5.8, 2.3, 2.0, 
    2.2, 2.0, 1.8, 1.9, 1.5, 5.5, 1.5, 2.4, 2.3, 5.5, 6.0, 6.1, 6.3, 6.3, 6.4, 
    6.4, 6.4, 6.3, 6.3, 6.2, 6.1, 6.0, 5.8, 5.4, 2.8, 2.0, 1.9, 3.6, 4.1, 4.5, 
    4.9, 5.1, 5.2, 5.4, 5.5, 5.5, 5.5, 5.4, 5.3, 5.1, 4.8
]

## Nuevamente definimos nuestros errores que van a ser constantes en nuestra escala
error_longitud_onda = 0.05
error_corriente = 0.02

## Hacemos las graficas con las barras de error
plt.figure(figsize=(12, 8))
plt.errorbar(longitud_onda, corriente, 
             xerr=error_longitud_onda, yerr=error_corriente, 
             fmt='o', linestyle='-', color='b', capsize=4, elinewidth=1, markeredgewidth=2, markersize=5)

## Creamos las etiquetas y el título de la gráfica
plt.xlabel('Longitud de onda (nm)')
plt.ylabel('Intensidad de corriente ($\times 10^{-4}$ A)')
plt.title('Gráfica de Longitud de onda vs Intensidad de corriente (Lámpara de Hidrógeno)')
plt.xlim(min(longitud_onda) - 10, max(longitud_onda) + 10)
plt.ylim(0, max(corriente) * 1.1)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Mercurio

# %%
import matplotlib.pyplot as plt

## Vaciamos los datos experimentales en dos arreglos
longitudes_de_onda = [300, 320, 340, 360, 380, 391, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 410, 415, 420, 425, 426, 427, 428, 429, 430, 431, 432, 434, 435, 450, 470, 490, 510, 520, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 560, 565, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 590, 600, 620, 640, 660, 680, 700, 720, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734, 735, 736, 737, 738, 739, 740, 760, 780, 800, 805, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 830, 840, 873, 874, 875, 876, 877, 878, 879, 880, 881, 882, 883, 884, 885]
intensidades_corriente = [0.9, 1.0, 1.7, 19.0, 5.0, 3.3, 4.0, 5.3, 6.9, 9.5, 20.0, 24.0, 27.0, 26.0, 25.0, 23.0, 20.0, 8.0, 7.0, 4.6, 7.0, 18.0, 25.0, 30.0, 32.0, 33.0, 34.0, 32.0, 32.0, 33.0, 3.5, 2.7, 3.2, 2.5, 25.0, 3.1, 3.3, 3.5, 3.7, 3.9, 4.0, 4.1, 4.1, 4.1, 4.0, 4.0, 4.0, 6.1, 22.0, 31.0, 34.0, 33.0, 33.0, 34.0, 44.0, 34.0, 33.0, 33.0, 33.0, 33.0, 34.0, 32.0, 28.0, 19.0, 9.0, 6.0, 5.0, 6.0, 7.0, 10.0, 14.0, 19.0, 23.0, 27.0, 31.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 30.0, 23.0, 14.0, 8.0, 5.0, 1.2, 1.0, 0.5, 0.5, 0.5, 0.8, 0.8, 1.2, 2.2, 2.8, 3.7, 4.5, 5.6, 6.2, 6.4, 6.5, 6.4, 5.9, 5.0, 4.0, 2.9, 2.0, 1.3, 1.0, 0.6, 0.5, 0.7, 1.2, 1.9, 2.3, 2.7, 3.2, 3.2, 3.3, 3.3, 3.3, 3.2, 2.8, 2.0, 1.5, 1.1, 0.9, 0.6, 0.6, 4.1, 5.4, 5.5, 5.6, 5.3, 5.0, 3.9, 2.7, 1.7, 0.9, 0.6, 0.5, 0.5]

## Definimos los errores que van a ser constantes en la escala que trabajamos
error_longitud_onda = 0.05
error_corriente = 0.02

## Hacemos las graficas con las barras de error 
plt.figure(figsize=(10, 6))
plt.errorbar(longitudes_de_onda, intensidades_corriente, 
             xerr=error_longitud_onda, yerr=error_corriente, 
             fmt='o', linestyle='-', color='b', capsize=4, elinewidth=1, markeredgewidth=2, markersize=5)

## Ponemos las etiquetas y títulos correspondientes en la gráfica
plt.xlabel('Longitud de onda (nm)')
plt.ylabel('Intensidad de corriente ($10^{-4}$ A)')
plt.title('Longitud de onda vs Intensidad de corriente')
plt.grid(True)
plt.show()
